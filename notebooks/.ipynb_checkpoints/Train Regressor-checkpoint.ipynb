# %% [markdown]
# # Seattle Airbnb Data
# The data I used in this notebook refer to over 3800 accommodations that where enlisted to Airbnb in Seattle during 2016. They describe a wide variety of features: not only information about hosts, locations and fares applied to each listing, but also their average ratings and availability period. These datasets are available for free download at https://www.kaggle.com/datasets/airbnb/seattle, where you can find more details and other interesting studies about them.

# %% [markdown]
# ## Train Regressors

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.linear_model import LinearRegression, ElasticNet 
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import r2_score, mean_squared_error
from sqlalchemy import create_engine
import pickle

import nltk
nltk.download(['punkt', 'wordnet', 'omw-1.4'])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\2100\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\2100\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\2100\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# #### Load data

# %%
engine = create_engine('sqlite:///../data/AirbnbRatings.db')
df = pd.read_sql('SELECT * FROM listings', engine)

# %%
X = df.drop(['review_scores_rating'], axis=1)
y = df.review_scores_rating

# %% [markdown]
# ### Write a tokenization function to process text data

# %%
def tokenize(text):
    
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()
    
    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### Build a machine learning pipeline
# This machine pipeline should take in as input
# - the `description` column
# - the most influential numeric columns in the dataset to predict ratings
#
# and output rating results.

# %%
numeric_features = list(X.columns)
text_feature = "description"
numeric_features.remove(text_feature)

# %%
preprocess = make_column_transformer(
    (Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize)),
        ('tfidf', TfidfTransformer())
    ]), text_feature),
    (StandardScaler(), numeric_features)
)

# %%
pipeline = Pipeline([
        ('preprocess', preprocess),
        ('reg', DecisionTreeRegressor())
])

# %% [markdown]
# ### Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('pipeline',
#                                                   Pipeline(steps=[('vect',
#                                                                    CountVectorizer(tokenizer=<function tokenize at 0x00000198294E6CA0>)),
#                                                                   ('tfidf',
#                                                                    TfidfTransformer())]),
#                                                   'description'),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['host_is_superhost_t',
#                                                    'host_response_time_within '
#                                                    'an hour',
#                                                    'host_identity_verified_t',
#                                                    'host_response_time_within '
#                                                    'a day',
#                                                    'instant_bookable_t',
#                                                    'cancellation_policy_flexible',
#                                                    'room_type_Private room',
#                                                    'property_type_House',
#                                                    'guests_included',
#                                                    'cancellation_policy_strict'])])),
#                 ('reg', DecisionTreeRegressor())])

# %%
pickle.dump(pipeline, open('../models/airbnb_pipeline.pkl', 'wb'))

# %% [markdown]
# ### Improve the model
# Use grid search to find better parameters.

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocess',
#    ColumnTransformer(transformers=[('pipeline',
#                                     Pipeline(steps=[('vect',
#                                                      CountVectorizer(tokenizer=<function tokenize at 0x00000198294E6CA0>)),
#                                                     ('tfidf',
#                                                      TfidfTransformer())]),
#                                     'description'),
#                                    ('standardscaler', StandardScaler(),
#                                     ['host_is_superhost_t',
#                                      'host_response_time_within an hour',
#                                      'host_identity_verified_t',
#                                      'host_response_time_within a day',
#                                      'instant_bookable_t',
#                                      'cancellation_policy_flexible',
#                                      'room_type_Private room',
#                                      'property_type_House', 'guests_included',
#                                      'cancellation_policy_strict'])])),
#   ('reg', DecisionTreeRegressor())],
#  'verbose': False,
#  'preprocess': ColumnTransformer(transformers=[('pipeline',
#                                   Pipeline(steps=[('vect',
#                                                    CountVectorizer(tokenizer=<function tokenize at 0x00000198294E6CA0>)),
#                                                   ('tfidf',
#                                                    TfidfTransformer())]),
#                                   'description'),
#                                  ('standardscaler', StandardScaler(),
#                                   ['host_is_superhost_t',
#                                    'host_response_time_within an hour',
#                                    'host_identity_verified_t',
#                                    'host_response_time_within a day',
#                                    'instant_bookable_t',
#                                    'cancellation_policy_flexible',
#                                    'room_type_Private room',
#                                    'property_type_House', 'guests_included',
#                                    'cancellation_policy_strict'])]),
#  'reg': DecisionTreeRegressor(),
#  'preprocess__n_jobs': None,
#  'preprocess__remainder': 'drop',
#  'preprocess__sparse_threshold': 0.3,
#  'preprocess__transformer_weights': None,
#  'preprocess__transformers': [('pipeline',
#    Pipeline(steps=[('vect',
#                     CountVectorizer(tokenizer=<function tokenize at 0x00000198294E6CA0>)),
#                    ('tfidf', TfidfTransformer())]),
#    'description'),
#   ('standardscaler',
#    StandardScaler(),
#    ['host_is_superhost_t',
#     'host_response_time_within an hour',
#     'host_identity_verified_t',
#     'host_response_time_within a day',
#     'instant_bookable_t',
#     'cancellation_policy_flexible',
#     'room_type_Private room',
#     'property_type_House',
#     'guests_included',
#     'cancellation_policy_strict'])],
#  'preprocess__verbose': False,
#  'preprocess__verbose_feature_names_out': True,
#  'preprocess__pipeline': Pipeline(steps=[('vect',
#                   CountVectorizer(tokenizer=<function tokenize at 0x00000198294E6CA0>)),
#                  ('tfidf', TfidfTransformer())]),
#  'preprocess__standardscaler': StandardScaler(),
#  'preprocess__pipeline__memory': None,
#  'preprocess__pipeline__steps': [('vect',
#    CountVectorizer(tokenizer=<function tokenize at 0x00000198294E6CA0>)),
#   ('tfidf', TfidfTransformer())],
#  'preprocess__pipeline__verbose': False,
#  'preprocess__pipeline__vect': CountVectorizer(tokenizer=<function tokenize at 0x00000198294E6CA0>),
#  'preprocess__pipeline__tfidf': TfidfTransformer(),
#  'preprocess__pipeline__vect__analyzer': 'word',
#  'preprocess__pipeline__vect__binary': False,
#  'preprocess__pipeline__vect__decode_error': 'strict',
#  'preprocess__pipeline__vect__dtype': numpy.int64,
#  'preprocess__pipeline__vect__encoding': 'utf-8',
#  'preprocess__pipeline__vect__input': 'content',
#  'preprocess__pipeline__vect__lowercase': True,
#  'preprocess__pipeline__vect__max_df': 1.0,
#  'preprocess__pipeline__vect__max_features': None,
#  'preprocess__pipeline__vect__min_df': 1,
#  'preprocess__pipeline__vect__ngram_range': (1, 1),
#  'preprocess__pipeline__vect__preprocessor': None,
#  'preprocess__pipeline__vect__stop_words': None,
#  'preprocess__pipeline__vect__strip_accents': None,
#  'preprocess__pipeline__vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'preprocess__pipeline__vect__tokenizer': <function __main__.tokenize(text)>,
#  'preprocess__pipeline__vect__vocabulary': None,
#  'preprocess__pipeline__tfidf__norm': 'l2',
#  'preprocess__pipeline__tfidf__smooth_idf': True,
#  'preprocess__pipeline__tfidf__sublinear_tf': False,
#  'preprocess__pipeline__tfidf__use_idf': True,
#  'preprocess__standardscaler__copy': True,
#  'preprocess__standardscaler__with_mean': True,
#  'preprocess__standardscaler__with_std': True,
#  'reg__ccp_alpha': 0.0,
#  'reg__criterion': 'squared_error',
#  'reg__max_depth': None,
#  'reg__max_features': None,
#  'reg__max_leaf_nodes': None,
#  'reg__min_impurity_decrease': 0.0,
#  'reg__min_samples_leaf': 1,
#  'reg__min_samples_split': 2,
#  'reg__min_weight_fraction_leaf': 0.0,
#  'reg__random_state': None,
#  'reg__splitter': 'best'}

# %%
parameters = {
        'preprocess__pipeline__vect__ngram_range': ((1, 1), (1, 2)),
        'preprocess__pipeline__vect__max_df': (0.5, 0.75, 1.0),
        'preprocess__pipeline__vect__max_features': (None, 5000, 10000),
        'preprocess__pipeline__tfidf__use_idf': (True, False),
        'reg': [ElasticNet(), DecisionTreeRegressor()]
    }

cv = GridSearchCV(pipeline, param_grid=parameters, verbose=20)

# %%
cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5; 1/72] START preprocess__pipeline__tfidf__use_idf=True, preprocess__pipeline__vect__max_df=0.5, preprocess__pipeline__vect__max_features=None, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet()
# [CV 1/5; 1/72] END preprocess__pipeline__tfidf__use_idf=True, preprocess__pipeline__vect__max_df=0.5, preprocess__pipeline__vect__max_features=None, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet();, score=0.045 total time=   3.6s
# [CV 2/5; 1/72] START preprocess__pipeline__tfidf__use_idf=True, preprocess__pipeline__vect__max_df=0.5, preprocess__pipeline__vect__max_features=None, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet()
# [CV 2/5; 1/72] END preprocess__pipeline__tfidf__use_idf=True, preprocess__pipeline__vect__max_df=0.5, preprocess__pipeline__vect__max_features=None, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet();, score=0.035 total time=   3.5s
# [CV 3/5; 1/72] START preprocess__pipeline__tfidf__use_idf=True, preprocess__pipeline__vect__max_df=0.5, preprocess__pipeline__vect__max_features=None, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet()
# [CV 3/5; 1/72] END preprocess__pipeline__tfidf__use_idf=True, preprocess__pipeline__vect__max_df=0.5, preprocess__pipeline__vect__max_features=None, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet();, score=0.051 total time=   3.6s
# [CV 4/5; 1/72] START preprocess__pipeline__tfidf__use_idf=True, preprocess__pipeline__vect__max_df=0.5, preprocess__pipeline__vect__max_features=None, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet()
# [CV 4/5; 1/72] END preprocess__pipeline__tfidf__use_idf=True, preprocess__pipeline__vect__max_df=0.5, preprocess__pipeline__vect__max_features=None, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet();, score=0.032 total time=   3.0s
# [CV 5/5; 1/72] START preprocess__pipeline__tfidf__use_idf=True, preprocess__pipeline__vect__max_df=0.5, preprocess__pipeline__vect__max_features=None, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet()
# [CV 5/5; 1/72] END preprocess__pipeline__tfidf__use_idf=True, preprocess__pipeline__vect__max_df=0.5, preprocess__pipeline__vect__max_features=None, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet();, score=0
72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=5000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor()
# [CV 4/5; 68/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=5000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor();, score=-0.370 total time=   4.8s
# [CV 5/5; 68/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=5000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor()
# [CV 5/5; 68/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=5000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor();, score=-0.610 total time=   4.3s
# [CV 1/5; 69/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet()
# [CV 1/5; 69/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet();, score=0.045 total time=   2.3s
# [CV 2/5; 69/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet()
# [CV 2/5; 69/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet();, score=0.035 total time=   3.1s
# [CV 3/5; 69/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet()
# [CV 3/5; 69/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet();, score=0.051 total time=   3.6s
# [CV 4/5; 69/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet()
# [CV 4/5; 69/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet();, score=0.032 total time=   3.3s
# [CV 5/5; 69/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet()
# [CV 5/5; 69/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=ElasticNet();, score=0.040 total time=   2.3s
# [CV 1/5; 70/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=DecisionTreeRegressor()
# [CV 1/5; 70/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=DecisionTreeRegressor();, score=-1.120 total time=   4.2s
# [CV 2/5; 70/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=DecisionTreeRegressor()
# [CV 2/5; 70/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=DecisionTreeRegressor();, score=-0.984 total time=   3.3s
# [CV 3/5; 70/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=DecisionTreeRegressor()
# [CV 3/5; 70/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=DecisionTreeRegressor();, score=-1.124 total time=   4.1s
# [CV 4/5; 70/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=DecisionTreeRegressor()
# [CV 4/5; 70/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=DecisionTreeRegressor();, score=-0.333 total time=   4.3s
# [CV 5/5; 70/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=DecisionTreeRegressor()
# [CV 5/5; 70/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 1), reg=DecisionTreeRegressor();, score=-0.645 total time=   3.4s
# [CV 1/5; 71/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=ElasticNet()
# [CV 1/5; 71/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=ElasticNet();, score=0.045 total time=   2.8s
# [CV 2/5; 71/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=ElasticNet()
# [CV 2/5; 71/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=ElasticNet();, score=0.035 total time=   3.1s
# [CV 3/5; 71/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=ElasticNet()
# [CV 3/5; 71/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=ElasticNet();, score=0.051 total time=   4.6s
# [CV 4/5; 71/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=ElasticNet()
# [CV 4/5; 71/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=ElasticNet();, score=0.032 total time=   4.3s
# [CV 5/5; 71/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=ElasticNet()
# [CV 5/5; 71/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=ElasticNet();, score=0.040 total time=   3.1s
# [CV 1/5; 72/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor()
# [CV 1/5; 72/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor();, score=-0.889 total time=   6.3s
# [CV 2/5; 72/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor()
# [CV 2/5; 72/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor();, score=-0.987 total time=   6.0s
# [CV 3/5; 72/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor()
# [CV 3/5; 72/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor();, score=-1.092 total time=   6.0s
# [CV 4/5; 72/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor()
# [CV 4/5; 72/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor();, score=-0.492 total time=   4.7s
# [CV 5/5; 72/72] START preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor()
# [CV 5/5; 72/72] END preprocess__pipeline__tfidf__use_idf=False, preprocess__pipeline__vect__max_df=1.0, preprocess__pipeline__vect__max_features=10000, preprocess__pipeline__vect__ngram_range=(1, 2), reg=DecisionTreeRegressor();, score=-0.494 total time=   5.8s
# GridSearchCV(estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('pipeline',
#                                                                          Pipeline(steps=[('vect',
#                                                                                           CountVectorizer(tokenizer=<function tokenize at 0x000001FE95DD5280>)),
#                                                                                          ('tfidf',
#                                                                                           TfidfTransformer())]),
#                                                                          'description'),
#                                                                         ('standardscaler',
#                                                                          StandardScaler(),
#                                                                          ['host_is_superhost_t',
#                                                                           'host_response_time_within '
#                                                                           'an '
#                                                                           'hour',
#                                                                           'host_identity_verif...
#                                                                           'cancellation_policy_strict'])])),
#                                        ('reg', DecisionTreeRegressor())]),
#              param_grid={'preprocess__pipeline__tfidf__use_idf': (True, False),
#                          'preprocess__pipeline__vect__max_df': (0.5, 0.75, 1.0),
#                          'preprocess__pipeline__vect__max_features': (None,
#                                                                       5000,
#                                                                       10000),
#                          'preprocess__pipeline__vect__ngram_range': ((1, 1),
#                                                                      (1, 2)),
#                          'reg': [ElasticNet(), DecisionTreeRegressor()]},
#              verbose=20)

# %%
pickle.dump(cv, open('../models/airbnb_gridsearch.pkl', 'wb'))

# %% [markdown]
# ### Test the model

# %%
cv = pickle.load(open('../models/airbnb_gridsearch.pkl', 'rb'))

# %%
y_pred_cv = cv.predict(X_test)

# %%
r2 = r2_score(y_test, y_pred_cv)
print("The R2 score of the model is {}".format(r2))
# Out:
# The R2 score of the model is 0.41561957028665497

# %%
mse = mean_squared_error(y_test, y_pred_cv)
print("The mean squared error of the model is {}".format(mse))
# Out:
# The mean squared error of the model is 42.73268765919611
